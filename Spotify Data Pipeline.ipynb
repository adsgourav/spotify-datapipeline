# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="819b78e0b6534f3c872ac5a78991aafe", client_secret="a2666e7670a84c4288fa4b4680499838")

# %%
sp = spotipy.Spotify(client_credentials_manager= client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/5MdJ5vdy8CZZdrm9yssGat"

# %%
playlist_URI = playlist_link.split("/")[-1]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]
# Out:
# {'added_at': '2025-01-31T13:24:35Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31xow5aivosfck7dmycpg35ydqqy'},
#   'href': 'https://api.spotify.com/v1/users/31xow5aivosfck7dmycpg35ydqqy',
#   'id': '31xow5aivosfck7dmycpg35ydqqy',
#   'type': 'user',
#   'uri': 'spotify:user:31xow5aivosfck7dmycpg35ydqqy'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/25OmZbss1JS6CdFqFDiaNu',
#    'id': '25OmZbss1JS6CdFqFDiaNu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273497b38a2a59095193de438d1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02497b38a2a59095193de438d1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851497b38a2a59095193de438d1',
#      'width': 64}],
#    'name': 'Ram Siya Ram (From "Adipurush")',
#    'release_date': '2023-05-29',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:25OmZbss1JS6CdFqFDiaNu',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#      'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#      'id': '1SyKki7JI1AZNKwgNMkn25',
#      'name': 'Sachet-Parampara',
#      'type': 'artist',
#      'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#      'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#      'id': '6WOdPJmexxFINcKMkP2jMG',
#      'name': 'Sachet Tandon',
#      'type': 'artist',
#      'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#      'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#      'id': '1E6arsXf5Fgsnv9YpSzjpE',
#      'name': 'Parampara Tandon',
#      'type': 'artist',
#      'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/25OmZbss1JS6CdFqFDiaNu'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#     'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#     'id': '1SyKki7JI1AZNKwgNMkn25',
#     'name': 'Sachet-Parampara',
#     'type': 'artist',
#     'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#     'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#     'id': '6WOdPJmexxFINcKMkP2jMG',
#     'name': 'Sachet Tandon',
#     'type': 'artist',
#     'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#     'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#     'id': '1E6arsXf5Fgsnv9YpSzjpE',
#     'name': 'Parampara Tandon',
#     'type': 'artist',
#     'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4cAERazLlAzVGA10ORWaUP'},
#     'href': 'https://api.spotify.com/v1/artists/4cAERazLlAzVGA10ORWaUP',
#     'id': '4cAERazLlAzVGA10ORWaUP',
#     'name': 'Manoj Muntashir',
#     'type': 'artist',
#     'uri': 'spotify:artist:4cAERazLlAzVGA10ORWaUP'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 230092,
#   'external_ids': {'isrc': 'INS182301552'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5aMLADD1Ho6Ogq8s8mIzB9'},
#   'href': 'https://api.spotify.com/v1/tracks/5aMLADD1Ho6Ogq8s8mIzB9',
#   'id': '5aMLADD1Ho6Ogq8s8mIzB9',
#   'name': 'Ram Siya Ram (From "Adipurush")',
#   'popularity': 65,
#   'uri': 'spotify:track:5aMLADD1Ho6Ogq8s8mIzB9',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
data['items'][0]['track']['album']['id']
# Out:
# '25OmZbss1JS6CdFqFDiaNu'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Ram Siya Ram (From "Adipurush")'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-05-29'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/25OmZbss1JS6CdFqFDiaNu'

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']

    album_element = {
        'album_id': album_id,
        'name' : album_name,
        'release_date' : album_release_date,
        'total_tracks' : album_total_tracks,
        'url' : album_url
    }

    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '25OmZbss1JS6CdFqFDiaNu',
#   'name': 'Ram Siya Ram (From "Adipurush")',
#   'release_date': '2023-05-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/25OmZbss1JS6CdFqFDiaNu'},
#  {'album_id': '3fNfYVLVvJAakhiI2Ukxxz',
#   'name': 'Namami Shamishan',
#   'release_date': '2024-02-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3fNfYVLVvJAakhiI2Ukxxz'},
#  {'album_id': '0a183xiCHiC1GQd8ou7WXO',
#   'name': 'ANIMAL',
#   'release_date': '2023-11-24',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/0a183xiCHiC1GQd8ou7WXO'},
#  {'album_id': '5Oxg8wfDhPIrEBM9Yz7ilI',
#   'name': 'Gadar 2 (Original Motion Picture Soundtrack)',
#   'release_date': '2023-08-05',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/5Oxg8wfDhPIrEBM9Yz7ilI'},
#  {'album_id': '5SKotVYCyEbrc2efbRMcsJ',
#   'name': 'Pardes (Original Motion Picture Soundtrack)',
#   'release_date': '1997-08-08',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/5SKotVYCyEbrc2efbRMcsJ'},
#  {'album_id': '4aNgfscxQSaTfrfPJZikIs',
#   'name': 'Upkar',
#   'release_date': '1968-01-01',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/4aNgfscxQSaTfrfPJZikIs'},
#  {'album_id': '4Uxt9DMRqqyFy1Ve6BuFte',
#   'name': 'Batti Gul Meter Chalu',
#   'release_date': '2018-09-08',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/4Uxt9DMRqqyFy1Ve6BuFte'},
#  {'album_id': '4YuDULq37hKS9dVVWwy9Jo',
#   'name': 'Baadshaho',
#   'release_date': '2017-08-19',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/4YuDULq37hKS9dVVWwy9Jo'},
#  {'album_id': '6eLhD8tvqlonibwg4g0Blc',
#   'name': 'Simroon Tera Naam (From "Yaariyan 2")',
#   'release_date': '2023-09-06',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6eLhD8tvqlonibwg4g0Blc'},
#  {'album_id': '1URshX6wM3IvvtYrGyuzYq',
#   'name': 'Reformed',
#   'release_date': '2017-03-16',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/1URshX6wM3IvvtYrGyuzYq'},
#  {'album_id': '1zLlgNA1tyiabDhDwWhyPG',
#   'name': 'Kali Kali Zulfon Ke (Lo-Fi)',
#   'release_date': '2023-03-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1zLlgNA1tyiabDhDwWhyPG'},
#  {'album_id': '25I49352TgeNPKyCtdwe5f',
#   'name': 'Ustad Nusrat Fateh Ali Khan',
#   'release_date': '2018-08-02',
#   'total_tracks': 25,
#   'url': 'https://open.spotify.com/album/25I49352TgeNPKyCtdwe5f'},
#  {'album_id': '4TJCkEg2d87LQ6CLjbmXee',
#   'name': 'Revamped, Vol. 3 (Remix)',
#   'release_date': '2022-02-18',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/4TJCkEg2d87LQ6CLjbmXee'},
#  {'album_id': '3I3kZyHUtEA9Y59rJkxtk6',
#   'name': 'Sajni (From "Laapataa Ladies")',
#   'release_date': '2024-02-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3I3kZyHUtEA9Y59rJkxtk6'},
#  {'album_id': '1pw0xzpe4O0OMohBwau50L',
#   'name': 'Bhediya (Original Motion Picture Soundtrack)',
#   'release_date': '2022-12-06',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1pw0xzpe4O0OMohBwau50L'},
#  {'album_id': '3I8PdIhk6pNm8Kv0HiF14V',
#   'name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")',
#   'release_date': '2019-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3I8PdIhk6pNm8Kv0HiF14V'},
#  {'album_id': '5mZX4EMwEyohNmVfLTDtXn',
#   'name': 'Satranga (From "ANIMAL")',
#   'release_date': '2023-10-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5mZX4EMwEyohNmVfLTDtXn'},
#  {'album_id': '6mOSDGo8ZREISAbaiTMW5J',
#   'name': 'Dunki',
#   'release_date': '2023-12-20',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/6mOSDGo8ZREISAbaiTMW5J'},
#  {'album_id': '0Rkv5iqjF2uenfL0OVB8hg',
#   'name': 'Aashiqui 2',
#   'release_date': '2013-04-06',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0Rkv5iqjF2uenfL0OVB8hg'},
#  {'album_id': '5Wm1nhxZqx7i0Hp6ZBqe9T',
#   'name': 'Love Forever With Arijit Singh',
#   'release_date': '2017-06-07',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/5Wm1nhxZqx7i0Hp6ZBqe9T'}]

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#   'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#   'id': '1SyKki7JI1AZNKwgNMkn25',
#   'name': 'Sachet-Parampara',
#   'type': 'artist',
#   'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#   'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#   'id': '6WOdPJmexxFINcKMkP2jMG',
#   'name': 'Sachet Tandon',
#   'type': 'artist',
#   'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#   'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#   'id': '1E6arsXf5Fgsnv9YpSzjpE',
#   'name': 'Parampara Tandon',
#   'type': 'artist',
#   'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4cAERazLlAzVGA10ORWaUP'},
#   'href': 'https://api.spotify.com/v1/artists/4cAERazLlAzVGA10ORWaUP',
#   'id': '4cAERazLlAzVGA10ORWaUP',
#   'name': 'Manoj Muntashir',
#   'type': 'artist',
#   'uri': 'spotify:artist:4cAERazLlAzVGA10ORWaUP'}]

# %%
data['items'][0]['track']['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#  'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#  'id': '1SyKki7JI1AZNKwgNMkn25',
#  'name': 'Sachet-Parampara',
#  'type': 'artist',
#  'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '1SyKki7JI1AZNKwgNMkn25'

# %%
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Sachet-Parampara'

# %%
data['items'][0]['track']['artists'][0]['href']
# Out:
# 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25'

# %%
artist_list = []
for row in data['items']:
    for key, values in row.items():
        if key == 'track':
            for artists in values['artists']:
                artists_id = artists['id']
                artists_name = artists['name']
                artists_url = artists['href']

                artists_element = {
                'artists_id': artists_id,
                'artists_name': artists_name,
                'artists_url' : artists_url
                }
                artist_list.append(artists_element)

# %%
artist_list
# Out:
# [{'artists_id': '1SyKki7JI1AZNKwgNMkn25',
#   'artists_name': 'Sachet-Parampara',
#   'artists_url': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25'},
#  {'artists_id': '6WOdPJmexxFINcKMkP2jMG',
#   'artists_name': 'Sachet Tandon',
#   'artists_url': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG'},
#  {'artists_id': '1E6arsXf5Fgsnv9YpSzjpE',
#   'artists_name': 'Parampara Tandon',
#   'artists_url': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE'},
#  {'artists_id': '4cAERazLlAzVGA10ORWaUP',
#   'artists_name': 'Manoj Muntashir',
#   'artists_url': 'https://api.spotify.com/v1/artists/4cAERazLlAzVGA10ORWaUP'},
#  {'artists_id': '25z75NKuPErImPddNQYD6g',
#   'artists_name': 'Religious India',
#   'artists_url': 'https://api.spotify.com/v1/artists/25z75NKuPErImPddNQYD6g'},
#  {'artists_id': '5wJ1H6ud777odtZl5gG507',
#   'artists_name': 'Vishal Mishra',
#   'artists_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artists_id': '2DFCHTDIA0t638a4mm37dK',
#   'artists_name': 'Raj Shekhar',
#   'artists_url': 'https://api.spotify.com/v1/artists/2DFCHTDIA0t638a4mm37dK'},
#  {'artists_id': '09UmIX92EUH9hAK4bxvHx6',
#   'artists_name': 'Mithoon',
#   'artists_url': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6'},
#  {'artists_id': '3ZxZ03fj3tXBZHZWzvaLSM',
#   'artists_name': 'Neeti Mohan',
#   'artists_url': 'https://api.spotify.com/v1/artists/3ZxZ03fj3tXBZHZWzvaLSM'},
#  {'artists_id': '5wJ1H6ud777odtZl5gG507',
#   'artists_name': 'Vishal Mishra',
#   'artists_url': 'https://api.spotify.com/v1/artists/5wJ1H6ud777odtZl5gG507'},
#  {'artists_id': '7azsQVtLmCegdKPs8a3bpi',
#   'artists_name': 'Shehnaz Akhtar',
#   'artists_url': 'https://api.spotify.com/v1/artists/7azsQVtLmCegdKPs8a3bpi'},
#  {'artists_id': '4gyOMCm7WGbBb1TGCepu7p',
#   'artists_name': 'Sahil Akhtar',
#   'artists_url': 'https://api.spotify.com/v1/artists/4gyOMCm7WGbBb1TGCepu7p'},
#  {'artists_id': '2pGRniGOJSOvYoK3dGaBb8',
#   'artists_name': 'Sayeed Quadri',
#   'artists_url': 'https://api.spotify.com/v1/artists/2pGRniGOJSOvYoK3dGaBb8'},
#  {'artists_id': '1dVygo6tRFXC8CSWURQJq2',
#   'artists_name': 'Sonu Nigam',
#   'artists_url': 'https://api.spotify.com/v1/artists/1dVygo6tRFXC8CSWURQJq2'},
#  {'artists_id': '7J1dPh3Yjs0aIhQHbBfNQP',
#   'artists_name': 'Hema Sardesai',
#   'artists_url': 'https://api.spotify.com/v1/artists/7J1dPh3Yjs0aIhQHbBfNQP'},
#  {'artists_id': '1SJOL9HJ08YOn92lFcYf8a',
#   'artists_name': 'Shankar Mahadevan',
#   'artists_url': 'https://api.spotify.com/v1/artists/1SJOL9HJ08YOn92lFcYf8a'},
#  {'artists_id': '4etv0ut4ws0GbXBtolzf5e',
#   'artists_name': 'Mukesh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4etv0ut4ws0GbXBtolzf5e'},
#  {'artists_id': '7pWXlTjky0KXWgbdZi9ebq',
#   'artists_name': 'Kalyanji-Anandji',
#   'artists_url': 'https://api.spotify.com/v1/artists/7pWXlTjky0KXWgbdZi9ebq'},
#  {'artists_id': '2oSONSC9zQ4UonDKnLqksx',
#   'artists_name': 'Atif Aslam',
#   'artists_url': 'https://api.spotify.com/v1/artists/2oSONSC9zQ4UonDKnLqksx'},
#  {'artists_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artists_name': 'Nusrat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artists_id': '3dN9MQpjIyNxyeRfz4EDZe',
#   'artists_name': 'Rochak Kohli',
#   'artists_url': 'https://api.spotify.com/v1/artists/3dN9MQpjIyNxyeRfz4EDZe'},
#  {'artists_id': '4cAERazLlAzVGA10ORWaUP',
#   'artists_name': 'Manoj Muntashir',
#   'artists_url': 'https://api.spotify.com/v1/artists/4cAERazLlAzVGA10ORWaUP'},
#  {'artists_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artists_name': 'Nusrat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artists_id': '3OLGltG8UPIea8sA4w0yg0',
#   'artists_name': 'Rahat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/3OLGltG8UPIea8sA4w0yg0'},
#  {'artists_id': '3pQ4aA7dkolyjUAMrVScgh',
#   'artists_name': 'Manan Bhardwaj',
#   'artists_url': 'https://api.spotify.com/v1/artists/3pQ4aA7dkolyjUAMrVScgh'},
#  {'artists_id': '6WOdPJmexxFINcKMkP2jMG',
#   'artists_name': 'Sachet Tandon',
#   'artists_url': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG'},
#  {'artists_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artists_name': 'Nusrat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artists_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artists_name': 'Nusrat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artists_id': '1aYNnNAn2f1l5FBMXvCsgK',
#   'artists_name': 'A1Melodymaster',
#   'artists_url': 'https://api.spotify.com/v1/artists/1aYNnNAn2f1l5FBMXvCsgK'},
#  {'artists_id': '2kfi47LWmlXzQ3p3kWonfQ',
#   'artists_name': 'Madhur Sharma',
#   'artists_url': 'https://api.spotify.com/v1/artists/2kfi47LWmlXzQ3p3kWonfQ'},
#  {'artists_id': '16023OFrIxSmKOMpIVJ6Ax',
#   'artists_name': 'Swapnil Tare',
#   'artists_url': 'https://api.spotify.com/v1/artists/16023OFrIxSmKOMpIVJ6Ax'},
#  {'artists_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artists_name': 'Nusrat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artists_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artists_name': 'Nusrat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artists_id': '5HcunTidTUrOaf8V0iJcvl',
#   'artists_name': 'Nusrat Fateh Ali Khan',
#   'artists_url': 'https://api.spotify.com/v1/artists/5HcunTidTUrOaf8V0iJcvl'},
#  {'artists_id': '2vgPHpzN3vUohpmQS7lNC7',
#   'artists_name': 'Afternight Vibes',
#   'artists_url': 'https://api.spotify.com/v1/artists/2vgPHpzN3vUohpmQS7lNC7'},
#  {'artists_id': '3PpjqSKBer3obW6lDflOBx',
#   'artists_name': 'Ram Sampath',
#   'artists_url': 'https://api.spotify.com/v1/artists/3PpjqSKBer3obW6lDflOBx'},
#  {'artists_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artists_name': 'Arijit Singh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artists_id': '7vCsTTACb2iT4fvBMnwp5w',
#   'artists_name': 'Prashant Pandey',
#   'artists_url': 'https://api.spotify.com/v1/artists/7vCsTTACb2iT4fvBMnwp5w'},
#  {'artists_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artists_name': 'Sachin-Jigar',
#   'artists_url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artists_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artists_name': 'Arijit Singh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artists_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artists_name': 'Amitabh Bhattacharya',
#   'artists_url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artists_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artists_name': 'Arijit Singh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artists_id': '09UmIX92EUH9hAK4bxvHx6',
#   'artists_name': 'Mithoon',
#   'artists_url': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6'},
#  {'artists_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artists_name': 'Arijit Singh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artists_id': '5o36rLQd78Zh8CaT8rn59d',
#   'artists_name': 'Shreyas Puranik',
#   'artists_url': 'https://api.spotify.com/v1/artists/5o36rLQd78Zh8CaT8rn59d'},
#  {'artists_id': '6k6TIai4KyKG1DeIMftSmJ',
#   'artists_name': 'Siddharth - Garima',
#   'artists_url': 'https://api.spotify.com/v1/artists/6k6TIai4KyKG1DeIMftSmJ'},
#  {'artists_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artists_name': 'Pritam',
#   'artists_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artists_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artists_name': 'Arijit Singh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artists_id': '3GdSQUH1BRtl9UrrtuwJlP',
#   'artists_name': 'Irshad Kamil',
#   'artists_url': 'https://api.spotify.com/v1/artists/3GdSQUH1BRtl9UrrtuwJlP'},
#  {'artists_id': '09UmIX92EUH9hAK4bxvHx6',
#   'artists_name': 'Mithoon',
#   'artists_url': 'https://api.spotify.com/v1/artists/09UmIX92EUH9hAK4bxvHx6'},
#  {'artists_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artists_name': 'Arijit Singh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artists_id': '3gBKY0y3dFFVRqicLnVZYz',
#   'artists_name': 'Alka Yagnik',
#   'artists_url': 'https://api.spotify.com/v1/artists/3gBKY0y3dFFVRqicLnVZYz'},
#  {'artists_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artists_name': 'Arijit Singh',
#   'artists_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'}]

# %%
data['items'][0]['track']['id']
# Out:
# '5aMLADD1Ho6Ogq8s8mIzB9'

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']

    song_element = {
        'song_id': song_id,
        'song_name':song_name,
        'duration_ms': song_duration,
        'url':song_url,
        'song_added':song_added,
        'album_id':album_id,
        'artist_id':artist_id
    }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '5aMLADD1Ho6Ogq8s8mIzB9',
#   'song_name': 'Ram Siya Ram (From "Adipurush")',
#   'duration_ms': 230092,
#   'url': 'https://open.spotify.com/track/5aMLADD1Ho6Ogq8s8mIzB9',
#   'song_added': '2025-01-31T13:24:35Z',
#   'album_id': '25OmZbss1JS6CdFqFDiaNu',
#   'artist_id': '1SyKki7JI1AZNKwgNMkn25'},
#  {'song_id': '3pQOhRPdlf1g3o0tek8akx',
#   'song_name': 'Namami Shamishan',
#   'duration_ms': 324168,
#   'url': 'https://open.spotify.com/track/3pQOhRPdlf1g3o0tek8akx',
#   'song_added': '2025-01-31T13:25:07Z',
#   'album_id': '3fNfYVLVvJAakhiI2Ukxxz',
#   'artist_id': '25z75NKuPErImPddNQYD6g'},
#  {'song_id': '7yDHHVKLbvDmVw1XXhDDIO',
#   'song_name': 'Pehle Bhi Main',
#   'duration_ms': 250158,
#   'url': 'https://open.spotify.com/track/7yDHHVKLbvDmVw1XXhDDIO',
#   'song_added': '2025-01-31T13:25:18Z',
#   'album_id': '0a183xiCHiC1GQd8ou7WXO',
#   'artist_id': '3pQ4aA7dkolyjUAMrVScgh'},
#  {'song_id': '4SSzOt6aKRnayBuKZsbTJc',
#   'song_name': 'Chal Tere Ishq Mein',
#   'duration_ms': 371101,
#   'url': 'https://open.spotify.com/track/4SSzOt6aKRnayBuKZsbTJc',
#   'song_added': '2025-01-31T13:25:35Z',
#   'album_id': '5Oxg8wfDhPIrEBM9Yz7ilI',
#   'artist_id': '09UmIX92EUH9hAK4bxvHx6'},
#  {'song_id': '1dZuiEX0EjvQai3N7BlUmT',
#   'song_name': 'Yeh Dil Deewana',
#   'duration_ms': 426400,
#   'url': 'https://open.spotify.com/track/1dZuiEX0EjvQai3N7BlUmT',
#   'song_added': '2025-01-31T13:25:54Z',
#   'album_id': '5SKotVYCyEbrc2efbRMcsJ',
#   'artist_id': '0xHXoShMJw3xDArjL8IHtt'},
#  {'song_id': '2pOk3ktgKol86qvTESSkzl',
#   'song_name': 'Diwano Se Mat Poochho',
#   'duration_ms': 217706,
#   'url': 'https://open.spotify.com/track/2pOk3ktgKol86qvTESSkzl',
#   'song_added': '2025-01-31T13:26:05Z',
#   'album_id': '4aNgfscxQSaTfrfPJZikIs',
#   'artist_id': '7pWXlTjky0KXWgbdZi9ebq'},
#  {'song_id': '1scGwkyXNCl19wrBDhnAWg',
#   'song_name': 'Dekhte Dekhte',
#   'duration_ms': 256271,
#   'url': 'https://open.spotify.com/track/1scGwkyXNCl19wrBDhnAWg',
#   'song_added': '2025-01-31T13:26:40Z',
#   'album_id': '4Uxt9DMRqqyFy1Ve6BuFte',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '4sNiMTu47WkUgW87qeUlWF',
#   'song_name': 'Mere Rashke Qamar',
#   'duration_ms': 220382,
#   'url': 'https://open.spotify.com/track/4sNiMTu47WkUgW87qeUlWF',
#   'song_added': '2025-01-31T13:26:43Z',
#   'album_id': '4YuDULq37hKS9dVVWwy9Jo',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '30Aof6iEIZDwYukcB98AOc',
#   'song_name': 'Simroon Tera Naam (From "Yaariyan 2")',
#   'duration_ms': 258130,
#   'url': 'https://open.spotify.com/track/30Aof6iEIZDwYukcB98AOc',
#   'song_added': '2025-01-31T13:26:44Z',
#   'album_id': '6eLhD8tvqlonibwg4g0Blc',
#   'artist_id': '3pQ4aA7dkolyjUAMrVScgh'},
#  {'song_id': '5wNpnKRUxbPoIpDXFZ5NkU',
#   'song_name': 'Sochta Houn',
#   'duration_ms': 277278,
#   'url': 'https://open.spotify.com/track/5wNpnKRUxbPoIpDXFZ5NkU',
#   'song_added': '2025-01-31T13:26:46Z',
#   'album_id': '1URshX6wM3IvvtYrGyuzYq',
#   'artist_id': '5HcunTidTUrOaf8V0iJcvl'},
#  {'song_id': '3mUkVsovIuscQlSoMhmAZt',
#   'song_name': 'Kali Kali Zulfon Ke (Lo-Fi)',
#   'duration_ms': 77252,
#   'url': 'https://open.spotify.com/track/3mUkVsovIuscQlSoMhmAZt',
#   'song_added': '2025-01-31T13:26:47Z',
#   'album_id': '1zLlgNA1tyiabDhDwWhyPG',
#   'artist_id': '2kfi47LWmlXzQ3p3kWonfQ'},
#  {'song_id': '3JpgL5TzK5mqcwjPUKlF54',
#   'song_name': 'Halka Halka Saroor',
#   'duration_ms': 434594,
#   'url': 'https://open.spotify.com/track/3JpgL5TzK5mqcwjPUKlF54',
#   'song_added': '2025-01-31T13:26:50Z',
#   'album_id': '25I49352TgeNPKyCtdwe5f',
#   'artist_id': '5HcunTidTUrOaf8V0iJcvl'},
#  {'song_id': '0Dg23zVaNGqUpEtKq9yoVn',
#   'song_name': 'Dil Pe Zakham Khate Hain',
#   'duration_ms': 284514,
#   'url': 'https://open.spotify.com/track/0Dg23zVaNGqUpEtKq9yoVn',
#   'song_added': '2025-01-31T13:26:51Z',
#   'album_id': '4TJCkEg2d87LQ6CLjbmXee',
#   'artist_id': '5HcunTidTUrOaf8V0iJcvl'},
#  {'song_id': '5zCnGtCl5Ac5zlFHXaZmhy',
#   'song_name': 'Sajni (From "Laapataa Ladies")',
#   'duration_ms': 170044,
#   'url': 'https://open.spotify.com/track/5zCnGtCl5Ac5zlFHXaZmhy',
#   'song_added': '2025-01-31T13:27:05Z',
#   'album_id': '3I3kZyHUtEA9Y59rJkxtk6',
#   'artist_id': '3PpjqSKBer3obW6lDflOBx'},
#  {'song_id': '1hA697u7e1jX2XM8sWA6Uy',
#   'song_name': 'Apna Bana Le',
#   'duration_ms': 261702,
#   'url': 'https://open.spotify.com/track/1hA697u7e1jX2XM8sWA6Uy',
#   'song_added': '2025-01-31T13:27:06Z',
#   'album_id': '1pw0xzpe4O0OMohBwau50L',
#   'artist_id': '1mBydYMVBECdDmMfE2sEUO'},
#  {'song_id': '2Fv2injs4qAm8mJBGaxVKU',
#   'song_name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")',
#   'duration_ms': 284779,
#   'url': 'https://open.spotify.com/track/2Fv2injs4qAm8mJBGaxVKU',
#   'song_added': '2025-01-31T13:27:07Z',
#   'album_id': '3I8PdIhk6pNm8Kv0HiF14V',
#   'artist_id': '4YRxDV8wJFPHPTeXepOstw'},
#  {'song_id': '3yHyiUDJdz02FZ6jfUbsmY',
#   'song_name': 'Satranga (From "ANIMAL")',
#   'duration_ms': 271169,
#   'url': 'https://open.spotify.com/track/3yHyiUDJdz02FZ6jfUbsmY',
#   'song_added': '2025-01-31T13:27:08Z',
#   'album_id': '5mZX4EMwEyohNmVfLTDtXn',
#   'artist_id': '4YRxDV8wJFPHPTeXepOstw'},
#  {'song_id': '6bmmHeCvZI92pRiTHxEdTC',
#   'song_name': 'O Maahi',
#   'duration_ms': 233453,
#   'url': 'https://open.spotify.com/track/6bmmHeCvZI92pRiTHxEdTC',
#   'song_added': '2025-01-31T13:27:09Z',
#   'album_id': '6mOSDGo8ZREISAbaiTMW5J',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '56zZ48jdyY2oDXHVnwg5Di',
#   'song_name': 'Tum Hi Ho',
#   'duration_ms': 261974,
#   'url': 'https://open.spotify.com/track/56zZ48jdyY2oDXHVnwg5Di',
#   'song_added': '2025-01-31T13:27:13Z',
#   'album_id': '0Rkv5iqjF2uenfL0OVB8hg',
#   'artist_id': '09UmIX92EUH9hAK4bxvHx6'},
#  {'song_id': '2FCXQHugkoHE1K3tiDu8pu',
#   'song_name': 'Agar Tum Saath Ho (From "Tamasha")',
#   'duration_ms': 341054,
#   'url': 'https://open.spotify.com/track/2FCXQHugkoHE1K3tiDu8pu',
#   'song_added': '2025-01-31T13:27:20Z',
#   'album_id': '5Wm1nhxZqx7i0Hp6ZBqe9T',
#   'artist_id': '4YRxDV8wJFPHPTeXepOstw'}]

# %%
album_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 album_df.info()
#
# NameError: name 'album_df' is not defined

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artists_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
album_df.head()

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()

# %%
song_df.head()

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])
